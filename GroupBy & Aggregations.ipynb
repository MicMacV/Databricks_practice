# %% [markdown]
# ## GroupBy & Aggregations

# %%
import pyspark

# %%
df = sqlContext.sql('SELECT * FROM sales_info_csv')

# %%
df.show(2)
# Out:
# +-------+-------+-----+
# |Company| Person|Sales|
# +-------+-------+-----+
# |   GOOG|    Sam|  200|
# |   GOOG|Charlie|  120|
# +-------+-------+-----+
# only showing top 2 rows

# %%
df.groupBy('Company').sum().show()
# Out:
# +-------+----------+
# |Company|sum(Sales)|
# +-------+----------+
# |   APPL|       250|
# |   GOOG|       660|
# |     FB|      1220|
# |   MSFT|       967|
# +-------+----------+

# %%
df.groupBy('Company')\
  .max('Sales')\
  .orderBy('max(Sales)', ascending=False)\
  .show()
# Out:
# +-------+----------+
# |Company|max(Sales)|
# +-------+----------+
# |     FB|       870|
# |   MSFT|       600|
# |   GOOG|       340|
# |   APPL|       250|
# +-------+----------+
